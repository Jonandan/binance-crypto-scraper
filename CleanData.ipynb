# %%
import pandas as pd

# %%
data=pd.read_csv('data.csv')

# %%
data=data[(data.iloc[:,1] !=0) &(data.iloc[:,2] !=0)]

# %%
print(data)
# Out:
#          Symbol         Price        Volume
# 0        ETHBTC      0.030550  1.474273e+04
# 1        LTCBTC      0.000759  1.662669e+04
# 2        BNBBTC      0.008412  2.246669e+04
# 3        NEOBTC      0.000039  1.786570e+03
# 4       QTUMETH      0.000465  3.541105e+05
# ...         ...           ...           ...
# 3557       WLDU      0.277400  1.725888e+05
# 3558  TRUMPUSD1      2.991000  7.055142e+03
# 3559    BTCUSDS  72336.000000  6.521200e-01
# 3560    ETHUSDS   2225.180000  1.588200e+00
# 3561   USDSUSDT      0.999500  2.546703e+06
#
# [2954 rows x 3 columns]

# %%
data.to_csv('CleanData.csv',index=False)
